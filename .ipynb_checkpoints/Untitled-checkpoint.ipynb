# %%
import re

# %%
testfile = open("timings.txt", "r")

# %%
file = testfile.read()

numbers = re.findall(r"[-+]?\d*\.\d+|\d+", file)

print(numbers)
# Out:
# ['0.021', '0.135', '3.208', '0.501', '22.861', '11.466', '0.242', '2.431', '29.821', '7.463', '13.092', '0.374', '7.348', '13.172', '0.249', '33.562', '12.316', '0.335', '2.501', '25.799', '5.514', '10.760', '0.230', '9.008', '12.577', '0.238', '26.829', '9.963', '0.158', '2.017', '25.228', '4.940', '10.934', '0.230', '5.603', '11.076', '0.212', '29.209', '14.462', '0.216', '2.592', '25.200', '4.764', '11.642', '0.169', '5.844', '10.479', '0.215', '25.517', '10.853', '0.229', '2.499', '25.378', '5.379', '10.649', '0.225', '5.686', '11.198', '0.171', '23.867', '10.382', '0.216', '2.162', '23.973', '4.896', '10.488', '0.225', '6.413', '11.121', '0.213', '24.165', '10.511', '0.203', '2.336', '24.194', '4.927', '11.326', '0.159', '6.166', '10.650', '0.220', '25.218', '11.223', '0.199', '1.911', '24.389', '5.028', '11.040', '0.210', '6.302', '10.483', '0.225', '25.061', '0.065', '1.010', '0.694', '1.095', '0.654', '1.019', '1.026', '1.115', '0.860', '1.088', '0.740', '0.996', '0.818', '1.
# ...

# %%
type(numbers)
# Out:
# list
